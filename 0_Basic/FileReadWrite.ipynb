# %%
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist

# "a" - Append - Opens a file for appending, creates the file if it does not exist

# "w" - Write - Opens a file for writing, creates the file if it does not exist

# "x" - Create - Creates the specified file, returns an error if the file exists
# "t" - Text - Default value. Text mode

# "b" - Binary - Binary mode (e.g. images)

# %%
import os


file="G://My Drive//MyPC//Python//0_Basic//New folder//demofile2.txt"

if os.path.exists(file):
    f = open(file=file, mode="r")
    print(f.read())
    f.close()
else:
    print("The file does not exist")

# %%
f = open(file=file, mode="a")
f.write("\n I am fine")
f.close()
f = open(file=file, mode="r")
print(f.read())
# Out:
#  I am fine

# %%
with open(file=file,mode="r") as Outpitfile:
   print(Outpitfile.read())
# Out:
#  I am fine

# %%
with open(file=file,mode="+tr") as Outpitfile:
   print(Outpitfile.truncate())
# Out:
# 0
