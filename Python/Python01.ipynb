# %%
x = str(3)
y = int(3)
z = float(3)

# %%
type(x), type(y), type(z)
# Out:
# (str, int, float)

# %%
x
# Out:
# '3'

# %%
print(x)
# Out:
# 3

# %%
a = "World"

def myfunction():
  a = "Kota"
  print("Hello "+a)

myfunction()
print(a)
# Out:
# Hello Kota
# World

# %%
def myfunction():
 global a
 a = "Kota"
 print("Hello "+a)

myfunction()
print(a)
# Out:
# Hello Kota
# Kota

# %%
print("""
Data Type:=>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
Text Type:        	str
Numeric Types:	    int, float, complex
Sequence Types:	    list, tuple, range
Mapping Type:	      dict
Set Types:	        set, frozenset
Boolean Type:	      bool
Binary Types:	      bytes, bytearray, memoryview
""")
# Out:
# Data Type:=>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Text Type:        	str
# Numeric Types:	    int, float, complex
# Sequence Types:	    list, tuple, range
# Mapping Type:	      dict
# Set Types:	        set, frozenset
# Boolean Type:	      bool
# Binary Types:	      bytes, bytearray, memoryview

# %%
x = ["apple", "banana", "cherry"]
x, type(x)
# Out:
# (['apple', 'banana', 'cherry'], list)

# %%
x = ("apple", "banana", "cherry")
x, type(x)
# Out:
# (('apple', 'banana', 'cherry'), tuple)

# %%
x = {"name" : "John", "age" : 36}
x, type(x)
# Out:
# ({'name': 'John', 'age': 36}, dict)

# %%
x = {"apple", "banana", "cherry"}
x, type(x)
# Out:
# ({'apple', 'banana', 'cherry'}, set)

# %%
x = range(6)
x, type(x)
# Out:
# (range(0, 6), range)

# %%
x = frozenset({"apple", "banana", "cherry"})
x, type(x)
# Out:
# (frozenset({'apple', 'banana', 'cherry'}), frozenset)

# %%
#Casting------------------------------------->>>>>>>>

# %%
x = float("3")
y = float(3)
z = float(2.5)
type(x),type(y),type(z)
# Out:
# (float, float, float)

# %%
for x in "banana":
  print(x)
  print(len(x))
# Out:
# b
# 1
# a
# 1
# n
# 1
# a
# 1
# n
# 1
# a
# 1

# %%
x = "HimanshuKashyap"
print(x[2:5]), print(x[:5])
# Out:
# man
# Himan
# (None, None)

# %%
x.upper(), x.lower(), x.strip(), x.replace("u","H"), x.split("u")
# Out:
# ('HIMANSHUKASHYAP',
#  'himanshukashyap',
#  'HimanshuKashyap',
#  'HimanshHKashyap',
#  ['Himansh', 'Kashyap'])

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
myorder.format(quantity, itemno, price)
# Out:
# 'I want 3 pieces of item 567 for 49.95 dollars.'
