# %%
myorder = "I have a {carname}, it is a {model}."
print(myorder.format(carname = "Ford", model = "Mustang"))
# Out:
# I have a Ford, it is a Mustang.

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {0} pieces of item number {1} for {2:.5f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00000 dollars.

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
username = input("Enter username:")
print("Username is: " + username)
# Out:
# Username is: 50

# %%
import json
x =  '{ "name":"John", "age":30, "city":"New York"}'
y = json.loads(x)
z = y['age']
print(z)
# Out:
# 30

# %%
# Convert to python to json
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}
y = json.dumps(x)
y
# Out:
# '{"name": "John", "age": 30, "city": "New York"}'

# %%
import datetime

x = datetime.datetime.now()
print(x)
print(x.year)
print(x.month)
print(x.day)
print(x.hour)
print(x.minute)
# Out:
# 2022-03-07 10:23:47.464561
# 2022
# 3
# 7
# 10
# 23

# %%
x = datetime.datetime(2020, 5, 17)
print(x)
print(x.year)
print(x.month)
print(x.day)
print(x.hour)
print(x.minute)
# Out:
# 2020-05-17 00:00:00
# 2020
# 5
# 17
# 0
# 0
