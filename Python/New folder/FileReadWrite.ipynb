# %%
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist

# "a" - Append - Opens a file for appending, creates the file if it does not exist

# "w" - Write - Opens a file for writing, creates the file if it does not exist

# "x" - Create - Creates the specified file, returns an error if the file exists
# "t" - Text - Default value. Text mode

# "b" - Binary - Binary mode (e.g. images)

# %%
f = open("D:\\Python\\Python\\New folder\\demofile2.txt", "x")
f.write("Hellow Himanshu")
f.close()

# %%
import os
if os.path.exists("D:\\Python\\Python\\New folder\\demofile2.txt"):
    f = open("D:\\Python\\Python\\New folder\\demofile2.txt", "r")
    print(f.read())
    f.close()
else:
    print("The file does not exist")
# Out:
# Hellow Himanshu

# %%
import os
if os.path.exists("D:\\Python\\Python\\New folder\\demofile2.txt"):
  os.remove("D:\\Python\\Python\\New folder\\demofile2.txt")
else:
  print("The file does not exist")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Python\Python\New folder\FileReadWrite.ipynb Cell 5 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/New%20folder/FileReadWrite.ipynb#ch0000029?line=0'>1</a> os.close(fd="remove")
#
# TypeError: an integer is required (got type str)

# %%
import os
#os.makedirs("D:\\Python\\Python\\New folder\\MyFolder")
#os.rmdir("myfolder")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Python\Python\New folder\FileReadWrite.ipynb Cell 5 in <module>
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/New%20folder/FileReadWrite.ipynb#ch0000024?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/New%20folder/FileReadWrite.ipynb#ch0000024?line=1'>2</a> #os.makedirs("D:\\Python\\Python\\New folder\\MyFolder")
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/New%20folder/FileReadWrite.ipynb#ch0000024?line=2'>3</a> os.rmdir("myfolder")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'myfolder'
