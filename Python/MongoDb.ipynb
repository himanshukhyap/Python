# %%
#djengo,flask,simplerest api

# %%
#pip install pip

# %%
#pip install pymongo

# %%
#pip install easydict

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
import requests
import pyodbc
import json
import collections
from bson import json_util

# %%
coingecko = 'https://api.coingecko.com/api/v3/coins/list?include_platform=false'
coincap =   'https://api.coincap.io/v2/assets/bitcoin'

# %%
def AddAssestManagerData(obj):
    myclient = pymongo.MongoClient("mongodb://localhost:27017/")
    mydb = myclient["Coin"]
    mycol = mydb["AssestManager"]
    mycol.insert_one(obj)

# def AddAssestDetailsData(obj):
#     myclient = pymongo.MongoClient("mongodb://localhost:27017/")
#     mydb = myclient["Coin"]
#     mycol = mydb["AssestDetails"]
#     mycol.insert_one(obj)

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=False, indent=2)
    print(text)

# %%
def SingleGetData(api):
        response = requests.get(api)
        if response.status_code == 200:
             doc = collections.OrderedDict()
             doc["AssestId"]=response.json()['id'], 
             doc['Symbol']= response.json()['symbol'], 
             doc['Name']= response.json()['name'] , 
             doc['Image']=response.json()['image']           
             obj1 = json.dumps(doc,default=json_util.default)
             #AddAssestManagerData(doc)
             print(doc)
        else:
            print("error SingleGetData")

# %%
def getAssestManagerData(api):
        response = requests.get(f"{api}")
        # print(response.status_code)
        # print(response.json())
        # print(response.text)
        if response.status_code == 200:
            for x in response.json(): 
                url= 'https://api.coingecko.com/api/v3/coins/{}'.format(x['id'])
                SingleGetData(url)            
        else:
            print("error")

# %%
getAssestManagerData(coingecko)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Python\Python\MongoDb.ipynb Cell 12 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=0'>1</a> getAssestManagerData(coingecko)
#
# d:\Python\Python\MongoDb.ipynb Cell 12 in getAssestManagerData(api)
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=6'>7</a>     for x in response.json():
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=7'>8</a>         url= 'https://api.coingecko.com/api/v3/coins/{}'.format(x['id'])
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=8'>9</a>         SingleGetData(url)
#      <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=9'>10</a> else:
# ...
