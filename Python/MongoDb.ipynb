# %%
#pip install pip

# %%
#pip install pymongo

# %%
#pip install easydict

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
import requests
import json
import shutil # save img locally

# %%
coingecko = 'https://api.coingecko.com/api/v3/coins/bitcoin'

# %%
    myclient = pymongo.MongoClient("mongodb://localhost:27017")
    mydb = myclient["Image"]
    mycol = mydb["CoinImage"]
    # mycol.insert_one()

# %%
def SingleGetData(api):
        response = requests.get(api,stream = True)
        if response.status_code == 200:
             print(response.json())
        else:
            print("error SingleGetData")

# %%
response = requests.get(url,stream = True)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Python\Python\MongoDb.ipynb Cell 9 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=0'>1</a> response = requests.get(url,stream = True)
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000009?line=1'>2</a> print(response)
#
# NameError: name 'url' is not defined

# %%
imgurl = 'https://assets.coingecko.com/coins/images/12000/thumb/683JEXMN_400x400.png?1596690527'
fileName = "D:\Python\Python\CoinImages.jpg"
print(type(imgurl))
response = requests.get(imgurl,stream = True)
if response.status_code == 200:
    with open(fileName,'wb') as f:
        shutil.copyfileobj(response.raw, f)
    print('Image sucessfully Downloaded: ',fileName)
else:
    print('Image Couldn\'t be retrieved')
# Out:
# <class 'str'>
# Image sucessfully Downloaded:  D:\Python\Python\CoinImages.jpg

# %%
pip install urllib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
import urllib.request

# %%
imgurl = 'https://assets.coingecko.com/coins/images/12000/thumb/683JEXMN_400x400.png?1596690527'
filepath = 'D:\Python\Python'
filename = 'Bitcoin'

# %%
def download_image(url, file_path, file_name):
    full_path = file_path + file_name + '.jpg'
    urllib.request.urlretrieve(url, full_path)

# %%
download_image(url=imgurl,file_path=filepath,file_name=filename)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# d:\Python\Python\MongoDb.ipynb Cell 15 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000014?line=0'>1</a> download_image(url=imgurl,file_path=filepath,file_name=filename)
#
# d:\Python\Python\MongoDb.ipynb Cell 15 in download_image(url, file_path, file_name)
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000014?line=0'>1</a> def download_image(url, file_path, file_name):
#       <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000014?line=1'>2</a>     full_path = file_path + file_name + '.jpg'
# ----> <a href='vscode-notebook-cell:/d%3A/Python/Python/MongoDb.ipynb#ch0000014?line=2'>3</a>     urllib.request.urlretrieve(url, full_path)
#
# File c:\Users\himan\anaconda3\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
# ...

# %%
response = requests.get(coingecko,stream = True)
print(list(response.json()['image'])[0])
# Out:
# thumb
