# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
index='A B C D E'.split()
columns ='W X Y Z'.split()
df = pd.DataFrame(randn(5,4),index,columns)
df
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %%
df[['W']]
# Out:
#           W
# A -0.088077
# B -1.474182
# C -0.627411
# D -0.141962
# E -1.666288

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A -0.088077  0.656202
# B -1.474182 -0.220686
# C -0.627411 -1.185047
# D -0.141962 -0.135632
# E -1.666288 -0.778031

# %% [markdown]
# DataFrame Columns are just Series

# %% [markdown]
# **Creating a new column:**

# %%
df['W+Y'] = df['W']+df['Y']
df
# Out:
#           W         X         Y         Z       W+Y
# A -0.088077 -1.324081 -1.138311  0.656202 -1.226389
# B -1.474182 -1.230227 -0.357559 -0.220686 -1.831741
# C -0.627411 -0.881035  2.250918 -1.185047  1.623507
# D -0.141962 -0.590400  1.579678 -0.135632  1.437716
# E -1.666288  0.065587  0.781274 -0.778031 -0.885014

# %% [markdown]
# ** Removing Columns**

# %%
df1=df.drop('W+Y',axis=1)
df1
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %%
df
# Out:
#           W         X         Y         Z       W+Y
# A -0.088077 -1.324081 -1.138311  0.656202 -1.226389
# B -1.474182 -1.230227 -0.357559 -0.220686 -1.831741
# C -0.627411 -0.881035  2.250918 -1.185047  1.623507
# D -0.141962 -0.590400  1.579678 -0.135632  1.437716
# E -1.666288  0.065587  0.781274 -0.778031 -0.885014

# %%
df.drop('W+Y',axis=1,inplace=True)
df
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc[['A']]
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[[2]]
# Out:
#           W         X         Y         Z
# C -0.627411 -0.881035  2.250918 -1.185047

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['B','Y']
# Out:
# -0.3575589474545163

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.088077 -1.138311
# B -1.474182 -0.357559

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False  False  False   True
# B  False  False  False  False
# C  False  False   True  False
# D  False  False   True  False
# E  False   True   True  False

# %%
df[df>0]
# Out:
#     W         X         Y         Z
# A NaN       NaN       NaN  0.656202
# B NaN       NaN       NaN       NaN
# C NaN       NaN  2.250918       NaN
# D NaN       NaN  1.579678       NaN
# E NaN  0.065587  0.781274       NaN

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %%
df
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.088077 -1.324081 -1.138311  0.656202
# 1     B -1.474182 -1.230227 -0.357559 -0.220686
# 2     C -0.627411 -0.881035  2.250918 -1.185047
# 3     D -0.141962 -0.590400  1.579678 -0.135632
# 4     E -1.666288  0.065587  0.781274 -0.778031

# %%
newind = 'CA NY WY OR CO'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df
# Out:
#           W         X         Y         Z
# A -0.088077 -1.324081 -1.138311  0.656202
# B -1.474182 -1.230227 -0.357559 -0.220686
# C -0.627411 -0.881035  2.250918 -1.185047
# D -0.141962 -0.590400  1.579678 -0.135632
# E -1.666288  0.065587  0.781274 -0.778031

# %%
df['States'] = newind
df
# Out:
#           W         X         Y         Z States
# A -0.088077 -1.324081 -1.138311  0.656202     CA
# B -1.474182 -1.230227 -0.357559 -0.220686     NY
# C -0.627411 -0.881035  2.250918 -1.185047     WY
# D -0.141962 -0.590400  1.579678 -0.135632     OR
# E -1.666288  0.065587  0.781274 -0.778031     CO

# %%
df.set_index('States')  # inplace by default False
# Out:
#                W         X         Y         Z
# States
# CA     -0.088077 -1.324081 -1.138311  0.656202
# NY     -1.474182 -1.230227 -0.357559 -0.220686
# WY     -0.627411 -0.881035  2.250918 -1.185047
# OR     -0.141962 -0.590400  1.579678 -0.135632
# CO     -1.666288  0.065587  0.781274 -0.778031

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.088077 -1.324081 -1.138311  0.656202     CA
# B -1.474182 -1.230227 -0.357559 -0.220686     NY
# C -0.627411 -0.881035  2.250918 -1.185047     WY
# D -0.141962 -0.590400  1.579678 -0.135632     OR
# E -1.666288  0.065587  0.781274 -0.778031     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA     -0.088077 -1.324081 -1.138311  0.656202
# NY     -1.474182 -1.230227 -0.357559 -0.220686
# WY     -0.627411 -0.881035  2.250918 -1.185047
# OR     -0.141962 -0.590400  1.579678 -0.135632
# CO     -1.666288  0.065587  0.781274 -0.778031

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1 -0.176636 -1.075619
#    2  0.515641 -0.422544
#    3  1.255709 -3.164028
# G2 1  0.302974  1.476400
#    2  0.933444 -0.345581
#    3  0.712796 -1.022706

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.176636 -1.075619
# 2  0.515641 -0.422544
# 3  1.255709 -3.164028

# %%
df.loc['G1'].loc[[1]]
# Out:
#           A         B
# 1 -0.176636 -1.075619

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.176636 -1.075619
#       2    0.515641 -0.422544
#       3    1.255709 -3.164028
# G2    1    0.302974  1.476400
#       2    0.933444 -0.345581
#       3    0.712796 -1.022706

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1   -0.176636 -1.075619
# 2    0.515641 -0.422544
# 3    1.255709 -3.164028

# %%
df.xs(['G1',1])
# Out:
# A   -0.176636
# B   -1.075619
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1    -0.176636 -1.075619
# G2     0.302974  1.476400

# %% [markdown]
# # Great Job!
